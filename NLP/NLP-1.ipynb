# %%
sample_text="Does this thing really works? Lets see."

# %%
import nltk

# %%
import sqlite3

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
words=word_tokenize(sample_text.lower())

# %%
sent_tokenize(sample_text)
# Out:
# ['Does this thing really works?', 'Lets see.']

# %%
from nltk.corpus import stopwords

# %%
stop=stopwords.words('english')

# %%
nltk.download('stopwords') # NLTK package for stop words
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/tanishqsaluja/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
clean_words=[w for w in words if not w in stop]

# %%
clean_words
# Out:
# ['thing', 'really', 'works', '?', 'lets', 'see', '.']

# %%
import string
punctuations=list(string.punctuation)

# %%
punctuations
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
stop=stop+punctuations # adding punctuations to stop list

# %%
# Stemming using NLTK
from nltk.stem import PorterStemmer

# %%
stem_words={'play','playing','player','played','happier','happying','briefly'}
ps = PorterStemmer()
stemmed_words = [ps.stem(w) for w in stem_words]
stemmed_words
# Out:
# ['play', 'play', 'player', 'briefli', 'happier', 'happi', 'play']

# %%
from nltk import pos_tag

# %%
from nltk.corpus import state_union

# %%
test = state_union.raw('2006-GWBush.txt')

# %%
nltk.download('state_union')
# Out:
# [nltk_data] Downloading package state_union to
# [nltk_data]     /home/tanishqsaluja/nltk_data...
# [nltk_data]   Unzipping corpora/state_union.zip.
# True

# %%
pos_tag(word_tokenize(test))
# Out:
# [('PRESIDENT', 'NNP'),
#  ('GEORGE', 'NNP'),
#  ('W.', 'NNP'),
#  ('BUSH', 'NNP'),
#  ("'S", 'POS'),
#  ('ADDRESS', 'NNP'),
#  ('BEFORE', 'IN'),
#  ('A', 'NNP'),
#  ('JOINT', 'NNP'),
#  ('SESSION', 'NNP'),
#  ('OF', 'IN'),
#  ('THE', 'NNP'),
#  ('CONGRESS', 'NNP'),
#  ('ON', 'NNP'),
#  ('THE', 'NNP'),
#  ('STATE', 'NNP'),
#  ('OF', 'IN'),
#  ('THE', 'NNP'),
#  ('UNION', 'NNP'),
#  ('January', 'NNP'),
#  ('31', 'CD'),
#  (',', ','),
#  ('2006', 'CD'),
#  ('THE', 'NNP'),
#  ('PRESIDENT', 'NNP'),
#  (':', ':'),
#  ('Thank', 'NNP'),
#  ('you', 'PRP'),
#  ('all', 'DT'),
#  ('.', '.'),
#  ('Mr.', 'NNP'),
#  ('Speaker', 'NNP'),
#  (',', ','),
#  ('Vice', 'NNP'),
#  ('President', 'NNP'),
#  ('Cheney', 'NNP'),
#  (',', ','),
#  ('members', 'NNS'),
#  ('of', 'IN'),
#  ('Congress', 'NNP'),
#  (',', ','),
#  ('members', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Supreme', 'NNP'),
#  ('Court', 'NNP'),
#  ('and', 'CC'),
#  ('diplomatic', 'JJ'),
#  ('corps', 'NN'),
#  (',', ','),
# ...

# %%
str1="Raj went for a walk"

# %%
pos_tag(word_tokenize(str1))
# Out:
# [('Raj', 'NNP'), ('went', 'VBD'), ('for', 'IN'), ('a', 'DT'), ('walk', 'NN')]

# %%
str2="raj went for a walk"

# %%
pos_tag(word_tokenize(str2))
# Out:
# [('raj', 'NN'), ('went', 'VBD'), ('for', 'IN'), ('a', 'DT'), ('walk', 'NN')]

# %%
str3="This painting is beautiful"

# %%
pos_tag(word_tokenize(str3))
# Out:
# [('This', 'DT'), ('painting', 'NN'), ('is', 'VBZ'), ('beautiful', 'JJ')]

# %%
str4="I have been painting since morning"

# %%
pos_tag(word_tokenize(str4))
# Out:
# [('I', 'PRP'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('painting', 'VBG'),
#  ('since', 'IN'),
#  ('morning', 'NN')]

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmitizer=WordNetLemmatizer()

# %%
lemmitizer.lemmatize("better",pos="a") # a means an adjective
# Out:
# 'good'

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/tanishqsaluja/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
lemmitizer.lemmatize("better",pos="n")
# Out:
# 'better'

# %%
lemmitizer.lemmatize("painting",pos="v")
# Out:
# 'paint'

# %%
def get_simple_pos(tag):
    if tag.startWith('J'):
        return wordnet.ADJ
    if tag.startWith('V'):
        return wordnet.VERB
    if tag.startWith('N'):
        return wordnet.NOUN
    if tag.startWith('R'):
        return wordnet.ADV
    return wordnet.NOUN
