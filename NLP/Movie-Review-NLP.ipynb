# %% [markdown]
# ## IMPORTING MODULES

# %%
import nltk

# %%
from nltk.corpus import movie_reviews

# %%
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /home/tanishqsaluja/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# True

# %% [markdown]
# ## DATA ANALYSIS

# %%
movie_reviews.categories() # Documents can be classified into negative and positive
# Out:
# ['neg', 'pos']

# %%
movie_reviews.fileids() # We have total 2000 documents
# Out:
# ['neg/cv000_29416.txt',
#  'neg/cv001_19502.txt',
#  'neg/cv002_17424.txt',
#  'neg/cv003_12683.txt',
#  'neg/cv004_12641.txt',
#  'neg/cv005_29357.txt',
#  'neg/cv006_17022.txt',
#  'neg/cv007_4992.txt',
#  'neg/cv008_29326.txt',
#  'neg/cv009_29417.txt',
#  'neg/cv010_29063.txt',
#  'neg/cv011_13044.txt',
#  'neg/cv012_29411.txt',
#  'neg/cv013_10494.txt',
#  'neg/cv014_15600.txt',
#  'neg/cv015_29356.txt',
#  'neg/cv016_4348.txt',
#  'neg/cv017_23487.txt',
#  'neg/cv018_21672.txt',
#  'neg/cv019_16117.txt',
#  'neg/cv020_9234.txt',
#  'neg/cv021_17313.txt',
#  'neg/cv022_14227.txt',
#  'neg/cv023_13847.txt',
#  'neg/cv024_7033.txt',
#  'neg/cv025_29825.txt',
#  'neg/cv026_29229.txt',
#  'neg/cv027_26270.txt',
#  'neg/cv028_26964.txt',
#  'neg/cv029_19943.txt',
#  'neg/cv030_22893.txt',
#  'neg/cv031_19540.txt',
#  'neg/cv032_23718.txt',
#  'neg/cv033_25680.txt',
#  'neg/cv034_29446.txt',
#  'neg/cv035_3343.txt',
#  'neg/cv036_18385.txt',
#  'neg/cv037_19798.txt',
# ...

# %%
len(movie_reviews.fileids("neg")) # We have 1000 documents each of negative and positive each
# Out:
# 1000

# %%
movie_reviews.words(movie_reviews.fileids()[5]) # List of words in the 5th review documents
# Out:
# ['capsule', ':', 'in', '2176', 'on', 'the', 'planet', ...]

# %% [markdown]
# ## FORM A DOCUMENT LIST OF TUPLES OF (LIST_OF_WORDS,CATEGORY)

# %%
documents=[]
for category in movie_reviews.categories():
    for fileid in movie_reviews.fileids(category):
        documents.append((movie_reviews.words(fileid),category))
documents[0:4]
# We have 1000 negative documents , followed by 1000 positive documents
# Out:
# [(['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...], 'neg'),
#  (['the', 'happy', 'bastard', "'", 's', 'quick', 'movie', ...], 'neg'),
#  (['it', 'is', 'movies', 'like', 'these', 'that', 'make', ...], 'neg'),
#  (['"', 'quest', 'for', 'camelot', '"', 'is', 'warner', ...], 'neg')]

# %%
# You may consider to set based on hard maximum limit instead of predefined hard-coded limit 
# (It will throws ValueError if you try yo set hard+1):
import resource
soft, hard = resource.getrlimit(resource.RLIMIT_NOFILE)
resource.setrlimit(resource.RLIMIT_NOFILE, (hard, hard))

# %%
# Randomly shuffling the documents
import random
random.shuffle(documents)

# %%
# Now the documents are shuffled
documents[0:4]
# Out:
# [(['synopsis', ':', 'sullen', 'julie', 'james', ',', ...], 'neg'),
#  (['one', 'of', 'kyle', 'mclachlan', "'", 's', 'earlier', ...], 'pos'),
#  (['the', 'caveman', "'", 's', 'valentine', 'starring', ...], 'pos'),
#  (['arye', 'cross', 'and', 'courteney', 'cox', 'star', ...], 'neg')]

# %% [markdown]
# ## IMPORT LEMMATIZER TO FIND ROOT WORD FOR EACH WORD OF REVIEW

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
from nltk.corpus import wordnet
## Function to convert the pos_tag returned part of speech into simpler form usable by lemmatizer
def get_simple_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ # a
    if tag.startswith('V'): 
        return wordnet.VERB # v
    if tag.startswith('N'): 
        return wordnet.NOUN # n
    if tag.startswith('R'): 
        return wordnet.ADV # r
    return wordnet.NOUN # n

# %% [markdown]
# ## CLEAN EACH REVIEW SUCH THAT IT DOESN'T CONTAIN ANY STOP WORD

# %%
def clean_review(words):
    output_words=[]
    for w in words:
        if w.lower() not in stop_words:
            # pos = pos_tag(word_tokenize(w))
            pos = pos_tag([w])
            clean_word = lemmatizer.lemmatize(w,pos=get_simple_pos(pos[0][1]))
            output_words.append(clean_word.lower())
    return output_words

# %%
from nltk import pos_tag # pos_tag tells us about type of word

# %%
print(pos_tag(word_tokenize("Eiffel Tower")))
print(pos_tag(word_tokenize("Big")))

# %%
from nltk import word_tokenize

# %%
print(pos_tag(["sd"]))
tag=pos_tag(["hello"])
tag[0][1].startswith('h')

# %% [markdown]
# ## FIND LIST OF ALL STOP WORDS INCLUDING PUNCTUATIONS

# %%
from nltk.corpus import stopwords
stop_words=list(stopwords.words('english'))

# %%
import string
puncts=list(string.punctuation)

# %%
stop_words=puncts+stop_words

# %% [markdown]
# ## MODIFYING THE CURRENT DOCUMENT BY CLEANING EACH REVIEW

# %%
documents=[(clean_review(document),category) for document,category in documents]

# %%
print(documents[0][1])
print(documents[0][0])
# Out:
# neg
# ...

# %% [markdown]
# ## SPLIT THE DATA

# %%
training_documents = documents[0:1500]
testing_documents = documents[1500:2000]

# %% [markdown]
# ## FORM A LIST OF ALL THE WORDS IN ALL THE CLEANED REVIEWS

# %%
all_words = []
for doc in training_documents:
    all_words += doc[0]

# %% [markdown]
# ## Using all_words list , select 3000 most frequently occuring words

# %%
freq=nltk.FreqDist(all_words)
common=freq.most_common(3000)
features=[i[0] for i in common] # We just want the word, not the number of occurences

# %%
features
# Out:
# ['film',
#  'movie',
#  'one',
#  'make',
#  'like',
#  'character',
#  'get',
#  'see',
#  'go',
#  'time',
#  'well',
#  'scene',
#  'even',
#  'good',
#  'story',
#  'take',
#  'would',
#  'bad',
#  'much',
#  'come',
#  'also',
#  'give',
#  'life',
#  'two',
#  'look',
#  'way',
#  'first',
#  'know',
#  '--',
#  'end',
#  'seem',
#  'year',
#  'work',
#  'thing',
#  'say',
#  'really',
#  'plot',
#  'play',
#  'show',
#  'little',
#  'people',
#  'star',
#  'love',
#  'never',
#  'could',
#  'director',
#  'man',
#  'new',
#  'try',
#  'best',
#  'great',
#  'performance',
#  'action',
#  'actor',
#  'many',
#  'big',
#  'want',
#  'watch',
#  'find',
#  'u',
#  'think',
#  'role',
#  'act',
#  'another',
#  'something',
#  'audience',
#  'world',
#  'back',
#  'turn',
#  'still',
#  'old',
#  'set',
#  'day',
#  'however',
#  'use',
#  'guy',
#  'every',
#  'feel',
#  'though',
#  'enough',
#  'cast',
#  'around',
#  'point',
#  'part',
#  'begin',
#  'interest',
#  'comedy',
# ...

# %%
def get_feature_dict(words):
    current_features = {} # this will be a dict
    word_set = set(words)
    for w in features:
        current_features[w] = w in word_set
    return current_features

# %% [markdown]
# #### TRAINING DATA WILL BE A TUPLE OF DICTIONARY OF FEATURES(True/False) AND CATEGORY FOR EACH REVIEW

# %%
training_data = [(get_feature_dict(doc),category) for doc,category in training_documents]

# %%
get_feature_dict(training_documents[10][0])
# Out:
# {'film': True,
#  'movie': False,
#  'one': True,
#  'make': True,
#  'like': True,
#  'character': True,
#  'get': True,
#  'see': True,
#  'go': False,
#  'time': True,
#  'well': True,
#  'scene': True,
#  'even': False,
#  'good': True,
#  'story': True,
#  'take': True,
#  'would': False,
#  'bad': False,
#  'much': True,
#  'come': False,
#  'also': True,
#  'give': False,
#  'life': True,
#  'two': True,
#  'look': False,
#  'way': True,
#  'first': False,
#  'know': True,
#  '--': True,
#  'end': True,
#  'seem': False,
#  'year': True,
#  'work': True,
#  'thing': False,
#  'say': False,
#  'really': False,
#  'plot': True,
#  'play': True,
#  'show': True,
#  'little': False,
#  'people': False,
#  'star': True,
#  'love': True,
#  'never': False,
#  'could': True,
#  'director': True,
#  'man': True,
#  'new': True,
#  'try': False,
#  'best': True,
#  'great': True,
#  'performance': True,
#  'action': False,
#  'actor': True,
#  'many': False,
#  'big': True,
# ...

# %%
testing_data = [(get_feature_dict(doc),category) for doc,category in testing_documents]

# %%
# training_data[0]

# %% [markdown]
# ## Use Naive Bayes Classifier for training

# %%
from nltk import NaiveBayesClassifier

# %%
classifier = NaiveBayesClassifier.train(training_data)

# %%
nltk.classify.accuracy(classifier,testing_data)
# Out:
# 0.788

# %%
classifier.show_most_informative_features(15)
# Out:
# Most Informative Features
#              outstanding = True              pos : neg    =     21.5 : 1.0
#                   turkey = True              neg : pos    =     18.9 : 1.0
#             breathtaking = True              pos : neg    =     11.1 : 1.0
#                stupidity = True              neg : pos    =     10.9 : 1.0
#               schumacher = True              neg : pos    =     10.3 : 1.0
#                    damon = True              pos : neg    =      9.9 : 1.0
#                    inept = True              neg : pos    =      9.2 : 1.0
#                ludicrous = True              neg : pos    =      8.4 : 1.0
#                   seagal = True              neg : pos    =      8.3 : 1.0
#               dreamworks = True              pos : neg    =      6.6 : 1.0
#                   alicia = True              neg : pos    =      6.2 : 1.0
#                    anger = True              pos : neg    =      5.9 : 1.0
# ...

# %%
lemmatizer.lemmatize("hello",wordnet.ADJ)
# Out:
# 'hello'

# %%
wordnet.ADJ
# Out:
# 'a'

# %% [markdown]
# ## Using sklearn classifier instead of NaiveBayes classifier in NLTK

# %%
from sklearn.svm import SVC
from nltk.classify.scikitlearn import SklearnClassifier

# %%
svc=SVC()
classifier_sklearn=SklearnClassifier(svc)

# %%
classifier_sklearn.train(training_data)
# Out:
# <SklearnClassifier(SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))>

# %%
nltk.classify.accuracy(classifier_sklearn,testing_data)
# Out:
# 0.774

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()
classifier_sklearn1=SklearnClassifier(rf)

# %%
classifier_sklearn1.train(training_data)
# Out:
# <SklearnClassifier(RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False))>

# %%
nltk.classify.accuracy(classifier_sklearn1,testing_data)
# Out:
# 0.66

# %% [markdown]
# ## Lemmatizer Practice

# %%
lemmatizer.lemmatize("good","a")
# Out:
# 'good'

# %%
lemmatizer.lemmatize("nice","a")
# Out:
# 'nice'

# %%
lemmatizer.lemmatize("better","a")
# Out:
# 'good'

# %%
print(pos_tag(["helping"]))
print(lemmatizer.lemmatize("helping","v"))
# Out:
# [('helping', 'VBG')]
# help

# %%
print(pos_tag(["helped"]))
print(lemmatizer.lemmatize("helped","v"))
# Out:
# [('helped', 'VBD')]
# help

# %% [markdown]
# ## RECONTINUING AFTER DATA CLEANING

# %%
documents=[(clean_review(document),category) for document,category in documents]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %% [raw]
# Count Vectorizer
# Uses and advantages :
#
#
# It keeps data in Sklearn required format.
#
#     1.Tokenisation: It convert a collection of text documents to a matrix of token counts.
#     2.Feature Extraction : It picks up the best features.
#     3.Sparse Matrix Creation: Converts each document into the frequency array, based upon the feautures we
#                               have chosen.

# %%
# dummy training data set 
training_set = {"the sky is blue sky", "the sun is bright"}

# create a count vectorizer object with max features to be 3
count_vec = CountVectorizer(max_features=3)

# On fit_transform on training data, Count Vectorizer actually picks the most frequent max_features(in this case 3) 
# number of words and then convert each training row into count/frequency for these features 
a = count_vec.fit_transform(training_set)

# It returns a sparse matrix i.e. where most of matrix contains 0
a.todense()
# Out:
# matrix([[1, 0, 1],
#         [1, 2, 1]], dtype=int64)

# %%
count_vec.get_feature_names()
# Out:
# ['is', 'sky', 'the']

# %%
a = ["he", "is"]
" ".join(a)
# Out:
# 'he is'

# %%
## Converting our document into x and y
categories = [category for document,category in documents] 
text_document = [" ".join(document) for document,category in documents]

# %%
## Train-Test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(text_document, categories, random_state = 0)

# %%
count_vec = CountVectorizer(max_features=2000)
## Fit transform the training data
x_train_features = count_vec.fit_transform(x_train)

## Only transform the testing data according to the features which was fit using x_train
x_test_features = count_vec.transform(x_test)

# %%
# Count Vectorizer

It keeps data in Sklearn required format.

    Tokenisation: It convert a collection of text documents to a matrix of token counts.
    Feature Extraction : It picks up the best features.
    Sparse Matrix Creation: Converts each document into the frequency array, based upon the feautures we have chosen.

Important Parameters:

   1. max_features - build a vocabulary that only consider the top max_features ordered by term frequency across the corpus.
   2. ngram_range : tuple (min_n, max_n) The lower and upper boundary of the range of n-values for different n-grams to be extracted. All values of n such that min_n <= n <= max_n will be used.
   3. analyzer : string, {‘word’, ‘char’, ‘char_wb’} or callable. Whether the feature should be made of word or character n-grams.

   4. max_df : float in range [0.0, 1.0] or int, default=1.0. When building the vocabulary ignore terms that have a document frequency strictly higher than the given threshold

   5. min_df : float in range [0.0, 1.0] or int, default=1. When building the vocabulary ignore terms that have a document frequency strictly lower than the given threshold. This value is also called cut-off in the literature.

Note:

    1. There is an option in count vectorizer(stop_words) which takes list of stop words and can do the work for us.
    2. It creates data with frequency counts earlier using nltk we were creating only boolean values for each features.
    3. Number of N-grams for a sentence with X words will be (X - N + 1)
    4. Use of N-Grams in your feature space may not necessarily yield any significant improvement.
# Out:
#   File "<ipython-input-107-3ccbf025cf63>", line 3
#     It keeps data in Sklearn required format.
#            ^
# SyntaxError: invalid syntax
